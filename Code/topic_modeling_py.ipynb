# %%
import pandas as pd
raw_corpus = pd.read_csv("~/Downlods/speech_w_data.csv", encoding = 'latin1')
headers = list(raw_corpus)

# %%
records = raw_corpus.loc[raw_corpus['congress_id'] >= 100, ['speech_id', 'speech']]

# %%
import nltk
import re
from nltk import word_tokenize          
from nltk.stem import SnowballStemmer 
class LemmaTokenizer(object):
     def __init__(self):
         self.wnl = SnowballStemmer(language = 'english')
     def __call__(self, doc):
        doc = re.sub(r'[^A-Za-z0-9\s]',r' ',doc)
        doc = re.sub(r'\n',r' ',doc)
        doc = re.sub(r'[0-9]',r' ',doc)
        #doc = re.sub(r'[a-z]\040' ,r'',doc) #remove singletons
        return [self.wnl.stem(t) for t in word_tokenize(doc)]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

no_features = 1500 #words

tfidf_vectorizer = TfidfVectorizer(tokenizer=LemmaTokenizer(), max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tfidf = tfidf_vectorizer.fit_transform(records['speech'])
tfidf_feature_names = tfidf_vectorizer.get_feature_names()

tf_vectorizer = CountVectorizer(tokenizer=LemmaTokenizer(), max_df=0.95, min_df=2, max_features=no_features, stop_words='english')
tf = tf_vectorizer.fit_transform(records['speech'])
tf_feature_names = tf_vectorizer.get_feature_names()

# %%
word_list = [tfidf_feature_names[np.asarray(tfidf.sum(0).argsort())[0][-i]] for i in range(no_features)]
print(pd.DataFrame(word_list))
pd.DataFrame(word_list).to_csv('../Data/list_of_{}words.csv'.format(no_features))

# %%
def display_topics(df, num_of_top_words = 10):
    for t in df.columns[1:] :
        words = df.sort_values(by = t, ascending = False)['word']
        print('topic {}: '.format(t) +", ".format(t).join([w for w in words[:num_of_top_words]] ))

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
no_topics = 75

# Run NMF
nmf = NMF(n_components=no_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# Run LDA
lda = LatentDirichletAllocation(n_components=no_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

# %%
dic = {'word' : tfidf_feature_names}
for t,l in enumerate(nmf.components_) :
    dic.update({ 'T{}'.format(t) : l})

word_75topics_NMF =pd.DataFrame(dic)
word_75topics_NMF.to_csv('../Data/word_75topics_NMF.csv')

dic = {'word' : tf_feature_names}
for t,l in enumerate(lda.components_) :
    dic.update({ 'T{}'.format(t) : l})

word_75topics_LDA = pd.DataFrame(dic)
word_75topics_LDA.to_csv('../Data/word_75topics_LDA.csv')

# %%
print("nmf:")
display_topics(word_75topics_NMF, num_of_top_words = 10)
# Out:
# nmf:
# topic T0: peopl, think, say, dont, want, know, thing, becaus, talk, just
# topic T1: iran, nuclear, agreement, deal, sanction, iranian, weapon, negoti, israel, regim
# topic T2: court, suprem, constitut, justic, scalia, decis, case, elect, law, v
# topic T3: famili, communiti, life, love, live, year, citi, young, day, honor
# topic T4: republican, democrat, leader, parti, hous, major, polit, shutdown, said, govern
# topic T5: veteran, va, affair, care, servic, medic, serv, homeless, employe, facil
# topic T6: school, educ, student, teacher, high, parent, state, kid, achiev, learn
# topic T7: secur, homeland, depart, border, dhs, threat, nation, social, protect, secretari
# topic T8: health, care, afford, medicar, patient, medicaid, access, medic, coverag, act
# topic T9: terrorist, attack, terror, intellig, threat, radic, fbi, islam, american, foreign
# topic T10: water, clean, flint, drink, california, lake, river, infrastructur, corp, michigan
# topic T11: committe, legisl, chairman, work, thank, member, bipartisan, import, support, rank
# topic T12: american, job, economi, america, peopl, econom, creat, percent, growth, manufactur
# topic T13: opioid, drug, addict, heroin, prescript, overdos, epidem, treatment, abus, pain
# topic T14: gun, violenc, background, check, shoot, buy, firearm, weapon, mass, kill
# topic T15: trade, agreement, tpa, negoti, currenc, export, promot, worker, deal, partnership
# topic T16: traffick, victim, human, sex, crime, girl, sexual, survivor, enforc, child
# topic T17: children, child, famili, parent, kid, flint, adopt, poverti, care, youth
# topic T18: puerto, rico, island, debt, territori, board, crisi, citizen, oversight, financi
# topic T19: presid, obama, constitut, execut, congress, law, power, administr, author, action
# topic T20: amend, offer, chairman, chair, mr, order, debat, balanc, process, gentleman
# topic T21: air, forc, command, clean, pollut, pilot, guard, base, train, oper
# topic T22: bank, exportimport, export, financi, reauthor, loan, credit, financ, institut, manufactur
# topic T23: oil, pipelin, keyston, export, gas, price, canada, produc, environment, product
# topic T24: tax, code, pay, credit, incom, reform, perman, corpor, cut, revenu
# topic T25: climat, chang, carbon, pollut, fossil, emiss, scientist, fuel, global, clean
# topic T26: cyber, inform, privaci, share, secur, threat, attack, intellig, data, protect
# topic T27: parenthood, plan, health, women, organ, clinic, cancer, center, screen, provid
# topic T28: zika, virus, mosquito, emerg, health, diseas, spread, public, control, florida
# topic T29: polic, offic, enforc, law, duti, protect, kill, communiti, line, depart
# topic T30: militari, defens, troop, nation, forc, author, arm, armi, servicememb, depart
# topic T31: transport, highway, infrastructur, bridg, road, project, rail, invest, longterm, safeti
# topic T32: energi, effici, electr, renew, gas, technolog, wind, power, clean, natur
# topic T33: food, label, consum, product, agricultur, inform, fda, farmer, vermont, farm
# topic T34: land, conserv, park, nation, feder, public, indian, area, manag, properti
# topic T35: student, loan, colleg, educ, univers, higher, borrow, financi, aid, graduat
# topic T36: immigr, deport, illeg, enforc, law, border, crimin, execut, reform, action
# topic T37: carolina, north, south, dakota, state, governor, florida, battl, black, coast
# topic T38: nomin, nomine, judg, confirm, judici, vacanc, senat, judiciari, attorney, presid
# topic T39: korea, north, nuclear, sanction, missil, regim, weapon, china, test, south
# topic T40: research, scienc, cancer, diseas, technolog, develop, innov, medic, space, scientif
# topic T41: busi, small, capit, louisiana, owner, creat, job, communiti, economi, grow
# topic T42: vote, right, voter, act, american, democrat, elect, march, pass, debat
# topic T43: fund, appropri, money, million, billion, fiscal, year, provid, spend, increas
# topic T44: rule, debat, committe, retir, resolut, process, labor, advic, protect, hous
# topic T45: women, men, equal, woman, pay, girl, discrimin, right, health, gap
# topic T46: mental, ill, health, treatment, help, crisi, hospit, suffer, need, treat
# topic T47: budget, cut, spend, balanc, fiscal, year, defens, billion, deficit, cap
# topic T48: religi, freedom, right, liberti, christian, religion, faith, belief, govern, human
# topic T49: justic, crimin, crime, prison, victim, black, sentenc, scalia, african, sexual
# topic T50: speaker, mr, hous, time, gentleman, yield, balanc, today, congress, consum
# topic T51: isi, syria, iraq, strategi, fight, islam, forc, defeat, syrian, east
# topic T52: feder, govern, agenc, requir, law, act, report, account, public, inform
# topic T53: program, reauthor, assist, senior, provid, benefit, help, support, grant, social
# topic T54: senat, floor, pass, presid, democrat, work, debat, leader, committe, bipartisan
# topic T55: r, h, act, support, consum, legisl, requir, provid, rise, speaker
# topic T56: forest, manag, servic, carbon, product, rural, borrow, season, disast, healthi
# topic T57: district, c, d, local, washington, citi, resid, employ, counti, school
# topic T58: refuge, syrian, syria, screen, unit, peopl, pari, countri, europ, crisi
# topic T59: obamacar, insur, premium, health, plan, coverag, exchang, afford, care, cost
# topic T60: compani, investor, financi, capit, invest, corpor, market, privat, industri, product
# topic T61: abort, babi, life, protect, pain, madam, week, human, medic, woman
# topic T62: dr, univers, king, educ, african, black, award, alabama, medic, histori
# topic T63: ir, employe, taxpay, target, servic, tax, investig, polit, revenu, agenc
# topic T64: war, vietnam, honor, ii, world, memori, armi, sacrific, soldier, veteran
# topic T65: debt, spend, money, trillion, pay, social, deficit, billion, year, borrow
# topic T66: coal, virginia, west, plant, electr, industri, power, job, wast, state
# topic T67: state, unit, s, u, foreign, countri, cuba, world, intern, nation
# topic T68: regul, regulatori, cost, financi, consum, agenc, chairman, administr, burden, economi
# topic T69: epa, chemic, clean, environment, standard, state, emiss, pollut, agenc, regul
# topic T70: nevada, ms, communiti, southern, congratul, wish, dedic, recogn, work, state
# topic T71: fish, speci, wildlif, manag, list, servic, ocean, lake, popul, protect
# topic T72: airport, aviat, secur, travel, screen, transport, intern, pilot, reauthor, improv
# topic T73: worker, wage, union, employ, labor, employe, work, pay, hour, elect
# topic T74: servic, serv, retir, career, dedic, univers, honor, offic, award, year

# %%
from sklearn.decomposition import NMF, LatentDirichletAllocation
num_of_topics = 25

# Run NMF
nmf = NMF(n_components=num_of_topics, random_state=1, alpha=.1, l1_ratio=.5, init='nndsvd').fit(tfidf)

# Run LDA
lda = LatentDirichletAllocation(n_components=num_of_topics, max_iter=5, learning_method='online', learning_offset=50.,random_state=0).fit(tf)

dic = {'word' : tfidf_feature_names}
for t,l in enumerate(nmf.components_) :
    dic.update({ 'T{}'.format(t) : l})

word_topics_NMF =pd.DataFrame(dic)
word_topics_NMF.to_csv('../Data/word_{}topics_NMF.csv'.format(num_of_topics))

dic = {'word' : tf_feature_names}
for t,l in enumerate(lda.components_) :
    dic.update({ 'T{}'.format(t) : l})

word_topics_LDA = pd.DataFrame(dic)
word_topics_LDA.to_csv('../Data/word_{}topics_LDA.csv'.format(num_of_topics))

print("nmf:")
display_topics(word_topics_NMF, num_of_top_words = 5)

print("LDA")
display_topics(word_topics_LDA, num_of_top_words = 5)
# Out:
# nmf:
# topic T0: peopl, say, want, think, dont
# topic T1: iran, nuclear, agreement, deal, sanction
# topic T2: court, suprem, nomine, judg, justic
# topic T3: serv, communiti, offic, honor, servic
# topic T4: budget, spend, debt, cut, republican
# topic T5: veteran, va, care, affair, servic
# topic T6: student, school, educ, colleg, teacher
# topic T7: secur, homeland, immigr, depart, border
# topic T8: health, care, insur, plan, women
# topic T9: amend, vote, chairman, offer, chair
# topic T10: water, epa, clean, drink, flint
# topic T11: senat, vote, republican, democrat, committe
# topic T12: energi, coal, electr, effici, technolog
# topic T13: opioid, drug, addict, heroin, prescript
# topic T14: gun, violenc, background, check, terrorist
# topic T15: trade, agreement, worker, tpa, negoti
# topic T16: fund, program, transport, highway, infrastructur
# topic T17: traffick, victim, human, sex, children
# topic T18: puerto, rico, zika, virus, debt
# topic T19: isi, terrorist, militari, defens, attack
# topic T20: rule, h, r, regul, act
# topic T21: climat, chang, carbon, pollut, emiss
# topic T22: bank, busi, small, exportimport, compani
# topic T23: oil, pipelin, keyston, export, gas
# topic T24: tax, pay, ir, code, credit
# LDA
# topic T0: trade, busi, job, american, compani
# topic T1: presid, republican, senat, vote, democrat
# topic T2: gun, drug, women, addict, victim
# topic T3: tax, budget, year, american, spend
# topic T4: law, enforc, offic, polic, communiti
# topic T5: senat, work, legisl, committe, bipartisan
# topic T6: money, taxpay, financi, bank, feder
# topic T7: terrorist, unit, state, world, war
# topic T8: health, care, plan, insur, american
# topic T9: water, state, land, epa, clean
# topic T10: rule, act, mr, regul, requir
# topic T11: secur, immigr, homeland, inform, depart
# topic T12: year, mr, nation, communiti, famili
# topic T13: research, climat, zika, puerto, chang
# topic T14: school, student, educ, children, state
# topic T15: energi, oil, state, gas, pipelin
# topic T16: senat, year, committe, opioid, s
# topic T17: veteran, va, militari, servic, care
# topic T18: iran, nuclear, agreement, deal, sanction
# topic T19: fund, appropri, hous, defens, budget
# topic T20: transport, infrastructur, state, highway, year
# topic T21: program, support, mr, provid, nation
# topic T22: court, right, justic, law, state
# topic T23: peopl, say, want, becaus, know
# topic T24: amend, mr, vote, time, think

# %%
def display_topics(df, num_of_top_words = 10):
    for t in df.columns[1:] :
        words = df.sort_values(by = t, ascending = False)['word']
        print('topic {}: '.format(t) +", ".format(t).join([w for w in words[:num_of_top_words]] ))

# %%
print("nmf:")
display_topics(word_topics_NMF, num_of_top_words = 10)

print("LDA")
display_topics(word_topics_LDA, num_of_top_words = 10)
# Out:
# nmf:
# topic T0: peopl, say, want, think, dont, know, becaus, thing, just, talk
# topic T1: iran, nuclear, agreement, deal, sanction, weapon, iranian, negoti, israel, regim
# topic T2: court, suprem, nomine, judg, justic, constitut, nomin, presid, confirm, vacanc
# topic T3: serv, communiti, offic, honor, servic, famili, life, year, polic, nation
# topic T4: budget, spend, debt, cut, republican, defens, trillion, billion, year, fiscal
# topic T5: veteran, va, care, affair, servic, militari, mental, serv, medic, homeless
# topic T6: student, school, educ, colleg, teacher, children, child, program, loan, parent
# topic T7: secur, homeland, immigr, depart, border, enforc, fund, dhs, cyber, law
# topic T8: health, care, insur, plan, women, parenthood, obamacar, afford, abort, coverag
# topic T9: amend, vote, chairman, offer, chair, debat, order, process, right, balanc
# topic T10: water, epa, clean, drink, flint, california, land, state, rule, river
# topic T11: senat, vote, republican, democrat, committe, work, presid, pass, leader, legisl
# topic T12: energi, coal, electr, effici, technolog, renew, gas, develop, power, clean
# topic T13: opioid, drug, addict, heroin, prescript, overdos, treatment, epidem, abus, pain
# topic T14: gun, violenc, background, check, terrorist, shoot, buy, firearm, kill, weapon
# topic T15: trade, agreement, worker, tpa, negoti, job, american, currenc, export, countri
# topic T16: fund, program, transport, highway, infrastructur, project, research, invest, need, billion
# topic T17: traffick, victim, human, sex, children, crime, child, enforc, crimin, sexual
# topic T18: puerto, rico, zika, virus, debt, island, mosquito, territori, crisi, emerg
# topic T19: isi, terrorist, militari, defens, attack, syria, refuge, war, forc, unit
# topic T20: rule, h, r, regul, act, speaker, agenc, feder, legisl, mr
# topic T21: climat, chang, carbon, pollut, emiss, scienc, fossil, scientist, clean, fuel
# topic T22: bank, busi, small, exportimport, compani, job, loan, financi, export, manufactur
# topic T23: oil, pipelin, keyston, export, gas, price, job, canada, produc, project
# topic T24: tax, pay, ir, code, credit, incom, american, corpor, reform, famili
# LDA
# topic T0: trade, busi, job, american, compani, countri, worker, economi, s, agreement
# topic T1: presid, republican, senat, vote, democrat, american, congress, obama, elect, peopl
# topic T2: gun, drug, women, addict, victim, traffick, violenc, abus, children, treatment
# topic T3: tax, budget, year, american, spend, pay, debt, percent, cut, work
# topic T4: law, enforc, offic, polic, communiti, citi, local, crimin, kill, protect
# topic T5: senat, work, legisl, committe, bipartisan, pass, import, colleagu, issu, togeth
# topic T6: money, taxpay, financi, bank, feder, loan, dollar, cost, billion, govern
# topic T7: terrorist, unit, state, world, war, american, presid, attack, peopl, isi
# topic T8: health, care, plan, insur, american, afford, obamacar, peopl, famili, patient
# topic T9: water, state, land, epa, clean, protect, forest, environment, fish, conserv
# topic T10: rule, act, mr, regul, requir, h, r, feder, consum, protect
# topic T11: secur, immigr, homeland, inform, depart, border, cyber, protect, threat, nation
# topic T12: year, mr, nation, communiti, famili, work, serv, honor, state, mani
# topic T13: research, climat, zika, puerto, chang, rico, scienc, health, virus, public
# topic T14: school, student, educ, children, state, colleg, child, program, teacher, parent
# topic T15: energi, oil, state, gas, pipelin, job, countri, year, product, coal
# topic T16: senat, year, committe, opioid, s, nomin, u, confirm, nomine, general
# topic T17: veteran, va, militari, servic, care, women, employe, serv, medic, provid
# topic T18: iran, nuclear, agreement, deal, sanction, state, weapon, presid, iranian, negoti
# topic T19: fund, appropri, hous, defens, budget, republican, need, depart, pass, billion
# topic T20: transport, infrastructur, state, highway, year, project, safeti, bridg, fund, road
# topic T21: program, support, mr, provid, nation, import, chairman, need, work, thank
# topic T22: court, right, justic, law, state, constitut, govern, suprem, case, act
# topic T23: peopl, say, want, becaus, know, just, dont, think, said, thing
# topic T24: amend, mr, vote, time, think, debat, want, chairman, say, committe
